# %% [markdown]
# # Working with JSON in Python

# %% [markdown]
# https://www.w3schools.com/js/js_json_intro.asp <br>
# <b>What is JSON?</b> <br>
# - JSON stands for JavaScript Object Notation
# - JSON is a lightweight data-interchange format
# - JSON is plain text written in JavaScript object notation
# - JSON is used to send data between computers
# - JSON is language independent (since it is just plain text)

# %% [markdown]
# <b>JSON syntax is derived from JavaScript object notation syntax:</b> <br>
#
# - Data is in name/value pairs
# - Data is separated by commas
# - Curly braces hold objects
# - Square brackets hold arrays

# %% [markdown]
# <b> JSON Values </b> <br>
# In JSON, values must be one of the following data types: <br>
#
# - a string
# - a number
# - an object
# - an array
# - a boolean
# - null

# %% [markdown]
# In JavaScript values can be all of the above, plus any other valid JavaScript expression, including: <br>
# - a function
# - a date
# - undefined

# %%
# Example JSON String
json_example1 = """
{
    "name": "John",
    "age": 30,
    "city": "New York"
}

"""

# %%
# Example JSON String
json_example2 = """
[
    {
        "teacher": "John",
        "age": 30,
        "school": "ABC Public School",
        "students": [
            "Harry",
            "Denise",
            "Rao"
        ]
    },
    {
        "teacher": "Sarah",
        "age": 30,
        "school": "XYZ Public School",
        "students": [
            "Bob",
            "Mary",
            "Lily"
        ]
    }
]

"""

# %% [markdown]
# ## Working with JSONs in Python

# %%
# The standard json library is used for working with JSON in Python
import json

# %% [markdown]
# #### Use json.loads() function to convert JSON strings to Python objects

# %%
# Use json.loads() function to convert JSOn strings to Python objects
json_example1_py = json.loads(json_example1)

json_example2_py = json.loads(json_example2)

# %%
json_example1_py
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York'}

# %%
json_example2_py
# Out:
# [{'teacher': 'John',
#   'age': 30,
#   'school': 'ABC Public School',
#   'students': ['Harry', 'Denise', 'Rao']},
#  {'teacher': 'Sarah',
#   'age': 30,
#   'school': 'XYZ Public School',
#   'students': ['Bob', 'Mary', 'Lily']}]

# %%
print(type(json_example1_py))
print(type(json_example2_py))
# Out:
# <class 'dict'>
# <class 'list'>

# %% [markdown]
# #### Use json.dumps() function to convert Pyhton objects to JSON strings

# %%
print("Dumping example1:")
print(json.dumps(json_example1_py))

print("\n\nDumping example2:")
print(json.dumps(json_example2_py))
# Out:
# Dumping example1:
# {"name": "John", "age": 30, "city": "New York"}
#
#
# Dumping example2:
# [{"teacher": "John", "age": 30, "school": "ABC Public School", "students": ["Harry", "Denise", "Rao"]}, {"teacher": "Sarah", "age": 30, "school": "XYZ Public School", "students": ["Bob", "Mary", "Lily"]}]

# %% [markdown]
# #### Use json.load() function load JSON data from file and convert to Pyhton objects

# %% [markdown]
# #### Use json.dump() function to convert Pyhton objects to JSON strings and write to file

# %%
with open('data/json_example1.json', 'w') as file:
    json.dump(json_example1_py, file)

with open('data/json_example2.json', 'w') as file:
    json.dump(json_example2_py, file)

# %%
# JSON formats are most commonly encountered in API responses
# We shall use an openly available API as an example
# Working with open AQ (air quality) data
# https://docs.openaq.org/docs/introduction

# %% [markdown]
# ## API Connection

# %%
import openaq

# %%
api_connection = openaq.OpenAQ()

# %% [markdown]
# ## API endpoint cities

# %%
status, resp = api_connection.cities()

# %%
status

# 200: Success
# 40x: Error: Bad Request
# 500: Server Error
# Out:
# 200

# %%
resp
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 4511,
#   'pages': 46},
#  'results': [{'country': 'DK', 'city': ' ', 'count': 23700, 'locations': 1},
#   {'country': 'KR', 'city': ' ', 'count': 13659586, 'locations': 712},
#   {'country': 'TT', 'city': ' ', 'count': 4231, 'locations': 1},
#   {'country': 'JP', 'city': ' ', 'count': 50762260, 'locations': 1594},
#   {'country': 'IT',
#    'city': ' Brescia Via San Polo',
#    'count': 5062,
#    'locations': 1},
#   {'country': 'IT',
#    'city': '- LOC. CASA STABBI - Chitignano (AR)',
#    'count': 63516,
#    'locations': 1},
#   {'country': 'IT',
#    'city': '-9999 - Acquapendente (VT)',
#    'count': 5943,
#    'locations': 1},
#   {'country': 'US', 'city': '007', 'count': 21375, 'locations': 3},
#   {'country': 'US', 'city': '015', 'count': 1135, 'locations': 1},
#   {'country': 'US', 'city': '039', 'count': 3093, 'locations': 1},
#   {'country': 'US', 'city': '047', 'count': 26504, 'locations': 4},
#   {'country': 'US', 'city': '063', 'count': 1323, 'locations': 1},
#   {'country': 'AT',
#    'city': '1010 Wien, Stephansplatz 1',
#    'count': 101292,
#    'locations': 1},
#   {'country': 'AT', 'city': '1020 Wien', 'count': 274166, 'locations': 2},
#   {'country': 'AT', 'city': '1070 Wien', 'count': 2466, 'locations': 1},
#   {'country': 'AT', 'city': '1090 Wien', 'count': 9612, 'locations': 1},
#   {'country': 'AT', 'city': '1100 Wien', 'count': 28029, 'locations': 1},
#   {'country': 'AT', 'city': '1110 Wien', 'count': 116055, 'locations': 1},
#   {'country': 'AT', 'city': '1120 Wien', 'count': 93475, 'locations': 1},
#   {'country': 'AT', 'city': '1130 Wien', 'count': 60883, 'locations': 1},
#   {'country': 'AT', 'city': '1160 Wien', 'count': 93696, 'locations': 1},
#   {'country': 'AT', 'city': '1180 Wien', 'count': 124719, 'locations': 1},
#   {'country': 'AT', 'city': '1190 Wien', 'count': 173782, 'locations': 2},
#   {'country': 'AT', 'city': '1210 Wien', 'count': 93659, 'locations': 1},
#   {'country': 'AT', 'city': '1220 Wien', 'count': 168555, 'locations': 2},
#   {'country': 'AT', 'city': '1230 Wien', 'count': 116601, 'locations': 2},
#   {'country': 'AT', 'city': '2000 Stockerau', 'count': 18659, 'locations': 1},
#   {'country': 'AT',
#    'city': '2073 Pillersdorf, Gemeinde Zellerndorf',
#    'count': 16880,
#    'locations': 1},
#   {'country': 'AT', 'city': '2120 Wolkersdorf', 'count': 7213, 'locations': 1},
#   {'country': 'AT', 'city': '2130 Mistelbach', 'count': 9556, 'locations': 1},
#   {'country': 'AT',
#    'city': '2230 Gänserndorf',
#    'count': 45809,
#    'locations': 1},
#   {'country': 'AT',
#    'city': '2301 Groß-Enzersdorf',
#    'count': 12793,
#    'locations': 1},
#   {'country': 'AT', 'city': '2320 Schwechat', 'count': 17783, 'locations': 1},
#   {'country': 'AT', 'city': '2325 Himberg', 'count': 6393, 'locations': 1},
#   {'country': 'AT', 'city': '2331 Vösendorf', 'count': 4067, 'locations': 1},
#   {'country': 'AT', 'city': '2340 Mödling', 'count': 173568, 'locations': 1},
#   {'country': 'AT',
#    'city': '2351 Wiener Neudorf ',
#    'count': 9613,
#    'locations': 1},
#   {'country': 'AT',
#    'city': '2362 Biedermannsdorf',
#    'count': 66523,
#    'locations': 1},
#   {'country': 'AT',
#    'city': '2410 Hainburg an der Donau',
#    'count': 16907,
#    'locations': 1},
#   {'country': 'SK', 'city': '2421 Kittsee', 'count': 13848, 'locations': 1},
#   {'country': 'AT',
#    'city': '2463 Trauttmannsdorf an der Leitha',
#    'count': 10378,
#    'locations': 1},
#   {'country': 'AT',
#    'city': '2533 Klausen-Leopoldsdorf',
#    'count': 10386,
#    'locations': 1},
#   {'country': 'AT', 'city': '2540 Bad Vöslau', 'count': 13724, 'locations': 1},
#   {'country': 'AT', 'city': '2650 Payerbach', 'count': 10387, 'locations': 1},
#   {'country': 'AT',
#    'city': '2700 Wiener Neustadt',
#    'count': 134978,
#    'locations': 1},
#   {'country': 'AT', 'city': '2811 Wiesmath', 'count': 31630, 'locations': 1},
#   {'country': 'AT', 'city': '3002 Purkersdorf', 'count': 7148, 'locations': 1},
#   {'country': 'AT', 'city': '3100 St. Pölten', 'count': 23935, 'locations': 2},
#   {'country': 'AT',
#    'city': '3111 Gratwein-Straßengel',
#    'count': 93825,
#    'locations': 1},
#   {'country': 'AT', 'city': '3222 Annaberg', 'count': 3179, 'locations': 1},
#   {'country': 'AT', 'city': '3300 Amstetten', 'count': 13580, 'locations': 1},
#   {'country': 'AT', 'city': '3323 Neustadtl', 'count': 6331, 'locations': 1},
#   {'country': 'AT',
#    'city': '3331 Kematen an der Ybbs',
#    'count': 104783,
#    'locations': 1},
#   {'country': 'AT', 'city': '3380 Pöchlarn', 'count': 7168, 'locations': 1},
#   {'country': 'AT',
#    'city': '3400 Klosterneuburg',
#    'count': 91374,
#    'locations': 2},
#   {'country': 'AT', 'city': '3430 Tulln', 'count': 150648, 'locations': 1},
#   {'country': 'AT', 'city': '3435 Zwentendorf', 'count': 9614, 'locations': 1},
#   {'country': 'AT', 'city': '3442 Langenrohr', 'count': 9695, 'locations': 1},
#   {'country': 'AT', 'city': '3453 Trasdorf', 'count': 16794, 'locations': 1},
#   {'country': 'AT', 'city': '3500 Krems', 'count': 132265, 'locations': 1},
#   {'country': 'AT',
#    'city': '3512 Bergern im Dunkelsteinerwald',
#    'count': 10363,
#    'locations': 1},
#   {'country': 'AT', 'city': '3710 Ziersdorf', 'count': 8263, 'locations': 1},
#   {'country': 'AT', 'city': '3754 Irnfritz', 'count': 6518, 'locations': 1},
#   {'country': 'AT',
#    'city': '3860 Heidenreichstein',
#    'count': 45561,
#    'locations': 1},
#   {'country': 'AT', 'city': '4020 Linz', 'count': 201517, 'locations': 4},
#   {'country': 'AT', 'city': '4050 Traun', 'count': 13633, 'locations': 1},
#   {'country': 'AT', 'city': '4221 Steyregg', 'count': 13632, 'locations': 1},
#   {'country': 'AT', 'city': '4264 Grünbach', 'count': 163237, 'locations': 1},
#   {'country': 'AT',
#    'city': '4300 St. Valentin',
#    'count': 13710,
#    'locations': 1},
#   {'country': 'AT', 'city': '4400 Steyr', 'count': 163554, 'locations': 1},
#   {'country': 'AT',
#    'city': '4462 Reichraming',
#    'count': 15090,
#    'locations': 1},
#   {'country': 'AT', 'city': '4470 Enns', 'count': 38904, 'locations': 1},
#   {'country': 'AT', 'city': '4600 Wels', 'count': 17627, 'locations': 1},
#   {'country': 'AT',
#    'city': '4761 Enzenkirchen',
#    'count': 16621,
#    'locations': 1},
#   {'country': 'AT', 'city': '4802 Ebensee', 'count': 41567, 'locations': 1},
#   {'country': 'AT', 'city': '4820 Bad Ischl', 'count': 43887, 'locations': 1},
#   {'country': 'AT',
#    'city': '4840 Vöcklabruck',
#    'count': 12860,
#    'locations': 1},
#   {'country': 'AT', 'city': '4860 Lenzing', 'count': 17070, 'locations': 1},
#   {'country': 'AT', 'city': '5020 Salzburg', 'count': 56339, 'locations': 3},
#   {'country': 'AT',
#    'city': '5071 Wals-Siezenheim',
#    'count': 6553,
#    'locations': 1},
#   {'country': 'AT',
#    'city': '5151 Nussdorf am Haunsberg',
#    'count': 70913,
#    'locations': 1},
#   {'country': 'AT',
#    'city': '5280 Braunau am Inn',
#    'count': 16672,
#    'locations': 1},
#   {'country': 'AT', 'city': '5400 Hallein', 'count': 87686, 'locations': 3},
#   {'country': 'AT',
#    'city': '5423 St. Koloman',
#    'count': 31412,
#    'locations': 1},
#   {'country': 'AT', 'city': '5580 Tamsweg', 'count': 10401, 'locations': 1},
#   {'country': 'AT', 'city': '5584 Zederhaus', 'count': 9812, 'locations': 1},
#   {'country': 'AT',
#    'city': '5600 St. Johann i. Pongau',
#    'count': 68929,
#    'locations': 1},
#   {'country': 'AT', 'city': '5661 Rauris', 'count': 8069, 'locations': 1},
#   {'country': 'AT',
#    'city': '5700 Zell am See',
#    'count': 42973,
#    'locations': 1},
#   {'country': 'AT', 'city': '6020 Innsbruck', 'count': 332194, 'locations': 5},
#   {'country': 'AT', 'city': '6060 Hall i.T.', 'count': 64027, 'locations': 1},
#   {'country': 'AT',
#    'city': '6134 Vomp bei Schwaz',
#    'count': 65272,
#    'locations': 1},
#   {'country': 'AT', 'city': '6230 Brixlegg', 'count': 63474, 'locations': 1},
#   {'country': 'AT', 'city': '6233 Kramsach', 'count': 70346, 'locations': 1},
#   {'country': 'AT', 'city': '6250 Kundl', 'count': 31464, 'locations': 1},
#   {'country': 'AT', 'city': '6300 Wörgl', 'count': 34478, 'locations': 1},
#   {'country': 'AT', 'city': '6330 Kufstein', 'count': 66322, 'locations': 2},
#   {'country': 'AT', 'city': '6460 Imst', 'count': 63713, 'locations': 1},
#   {'country': 'AT',
#    'city': '6580 St. Anton am Arlberg',
#    'count': 3259,
#    'locations': 1},
#   {'country': 'AT', 'city': '6600 Reutte', 'count': 31198, 'locations': 1}]}

# %%
type(resp)
# Out:
# dict

# %%
# the response is in JSON format and is represented in python as a dictionary

len(resp)
# Out:
# 2

# %%
# What are the entries in the dictionary
resp.keys()
# Out:
# dict_keys(['meta', 'results'])

# %%
# The first entry in the dictionary is the metadata of the API response
resp['meta']

# This shows that page 1 of 46 pages was returned, this page contains 100 items
# Out:
# {'name': 'openaq-api',
#  'license': '',
#  'website': '/',
#  'page': 1,
#  'limit': 100,
#  'found': 4511,
#  'pages': 46}

# %%
# The second entry is a list of 100 items. As indicated in the metadata
print(type(resp['results']))
print(len(resp['results']))
# Out:
# <class 'list'>
# 100

# %%
# Each item is again a dictionary
type(resp['results'][1])
# Out:
# dict

# %%
resp['results'][1].keys()
# Out:
# dict_keys(['country', 'city', 'count', 'locations'])

# %% [markdown]
# ## API endpoint locations

# %%
status, locations_india = api_connection.locations(country = "IN")

# %%
locations_india
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 436,
#   'pages': 5},
#  'results': [{'id': 5644,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Sanegurava Halli, Bengaluru - KSPCB',
#    'locations': ['Sanegurava Halli, Bengaluru - KSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 12.990328, 'longitude': 77.5431385},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'so2', 'no2', 'co'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 36241},
#     {'parameter': 'so2 µg/m³', 'count': 36371},
#     {'parameter': 'no2 µg/m³', 'count': 36502},
#     {'parameter': 'co µg/m³', 'count': 36954}],
#    'count': 146068},
#   {'id': 407,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Zoo Park, Hyderabad - TSPCB',
#    'locations': ['Zoo Park, Hyderabad - TSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 17.349694, 'longitude': 78.451437},
#    'firstUpdated': '2016-03-21T19:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'pm25', 'co', 'o3', 'no2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 58994},
#     {'parameter': 'pm25 µg/m³', 'count': 57115},
#     {'parameter': 'co µg/m³', 'count': 58985},
#     {'parameter': 'o3 µg/m³', 'count': 54143},
#     {'parameter': 'no2 µg/m³', 'count': 58624},
#     {'parameter': 'pm10 µg/m³', 'count': 53654}],
#    'count': 341515},
#   {'id': 270777,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Jigar Colony, Moradabad - UPPCB',
#    'locations': ['Jigar Colony, Moradabad - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.856664, 'longitude': 78.77263800000001},
#    'firstUpdated': '2021-12-18T08:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'pm10', 'co', 'no2', 'o3', 'so2'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 3375},
#     {'parameter': 'pm10 µg/m³', 'count': 3375},
#     {'parameter': 'co µg/m³', 'count': 3375},
#     {'parameter': 'no2 µg/m³', 'count': 3375},
#     {'parameter': 'o3 µg/m³', 'count': 3375},
#     {'parameter': 'so2 µg/m³', 'count': 3375}],
#    'count': 20250},
#   {'id': 2596,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Solapur, Solapur - MPCB',
#    'locations': ['Solapur, Solapur - MPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 17.6599188, 'longitude': 75.9063906},
#    'firstUpdated': '2016-03-21T19:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'co', 'pm25', 'o3', 'no2', 'so2'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 50358},
#     {'parameter': 'co µg/m³', 'count': 50521},
#     {'parameter': 'pm25 µg/m³', 'count': 49808},
#     {'parameter': 'o3 µg/m³', 'count': 50776},
#     {'parameter': 'no2 µg/m³', 'count': 50751},
#     {'parameter': 'so2 µg/m³', 'count': 50759}],
#    'count': 302973},
#   {'id': 6928,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Vasai West, Mumbai - MPCB',
#    'locations': ['Vasai West, Mumbai - MPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 19.3832, 'longitude': 72.8204},
#    'firstUpdated': '2019-06-19T00:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'co', 'o3', 'pm10', 'so2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 20451},
#     {'parameter': 'co µg/m³', 'count': 19206},
#     {'parameter': 'o3 µg/m³', 'count': 8641},
#     {'parameter': 'pm10 µg/m³', 'count': 17351},
#     {'parameter': 'so2 µg/m³', 'count': 18704},
#     {'parameter': 'pm25 µg/m³', 'count': 20812}],
#    'count': 105165},
#   {'id': 358452,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Chalai Bazaar, Ramanathapuram - TNPCB',
#    'locations': ['Chalai Bazaar, Ramanathapuram - TNPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 9.36399, 'longitude': 78.831977},
#    'firstUpdated': '2022-09-13T12:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'no2', 'pm10', 'so2', 'pm25', 'co'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 508},
#     {'parameter': 'no2 µg/m³', 'count': 504},
#     {'parameter': 'pm10 µg/m³', 'count': 523},
#     {'parameter': 'so2 µg/m³', 'count': 513},
#     {'parameter': 'pm25 µg/m³', 'count': 518},
#     {'parameter': 'co µg/m³', 'count': 504}],
#    'count': 3070},
#   {'id': 10609,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Hebbal 1st Stage, Mysuru - KSPCB',
#    'locations': ['Hebbal 1st Stage, Mysuru - KSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 12.210409999999998, 'longitude': 76.37376},
#    'firstUpdated': '2020-01-03T12:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'o3', 'no2', 'co', 'pm25', 'so2'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 15343},
#     {'parameter': 'o3 µg/m³', 'count': 15346},
#     {'parameter': 'no2 µg/m³', 'count': 15348},
#     {'parameter': 'co µg/m³', 'count': 15348},
#     {'parameter': 'pm25 µg/m³', 'count': 15342},
#     {'parameter': 'so2 µg/m³', 'count': 15351}],
#    'count': 92078},
#   {'id': 10780,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Manali Village, Chennai - TNPCB',
#    'locations': ['Manali Village, Chennai - TNPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 13.166200000000002, 'longitude': 80.2584},
#    'firstUpdated': '2019-07-19T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'co', 'pm25', 'pm10', 'no2', 'o3'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 22726},
#     {'parameter': 'co µg/m³', 'count': 22727},
#     {'parameter': 'pm25 µg/m³', 'count': 22712},
#     {'parameter': 'pm10 µg/m³', 'count': 22719},
#     {'parameter': 'no2 µg/m³', 'count': 22726},
#     {'parameter': 'o3 µg/m³', 'count': 22726}],
#    'count': 136336},
#   {'id': 8153,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Urban, Chamarajanagar - KSPCB',
#    'locations': ['Urban, Chamarajanagar - KSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 11.553579999999998, 'longitude': 76.55521},
#    'firstUpdated': '2020-01-03T12:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'no2', 'pm25', 'pm10', 'o3', 'co'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 9676},
#     {'parameter': 'no2 µg/m³', 'count': 9675},
#     {'parameter': 'pm25 µg/m³', 'count': 9673},
#     {'parameter': 'pm10 µg/m³', 'count': 9686},
#     {'parameter': 'o3 µg/m³', 'count': 9680},
#     {'parameter': 'co µg/m³', 'count': 9676}],
#    'count': 58066},
#   {'id': 8039,
#    'country': 'IN',
#    'city': 'Mumbai',
#    'cities': ['Mumbai'],
#    'location': 'US Diplomatic Post: Mumbai',
#    'locations': ['US Diplomatic Post: Mumbai'],
#    'sourceName': 'StateAir Mumbai',
#    'sourceNames': ['StateAir Mumbai'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 19.07283, 'longitude': 72.88261},
#    'firstUpdated': '2016-11-09T19:00:00+00:00',
#    'lastUpdated': '2024-08-23T11:30:00+00:00',
#    'parameters': ['pm25'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 62919}],
#    'count': 62919},
#   {'id': 60656,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Tamaka Ind. Area, Kolar - KSPCB',
#    'locations': ['Tamaka Ind. Area, Kolar - KSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 13.1276288, 'longitude': 78.1570122},
#    'firstUpdated': '2021-01-12T11:45:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'so2', 'pm10', 'o3', 'no2', 'co'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 2841},
#     {'parameter': 'so2 µg/m³', 'count': 3383},
#     {'parameter': 'pm10 µg/m³', 'count': 3401},
#     {'parameter': 'o3 µg/m³', 'count': 3302},
#     {'parameter': 'no2 µg/m³', 'count': 3338},
#     {'parameter': 'co µg/m³', 'count': 1155}],
#    'count': 17420},
#   {'id': 5665,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Vasundhara, Ghaziabad - UPPCB',
#    'locations': ['Vasundhara, Ghaziabad - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.6603346, 'longitude': 77.3572563},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'pm10', 'no2', 'so2', 'o3', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 47569},
#     {'parameter': 'pm10 µg/m³', 'count': 45996},
#     {'parameter': 'no2 µg/m³', 'count': 47546},
#     {'parameter': 'so2 µg/m³', 'count': 47583},
#     {'parameter': 'o3 µg/m³', 'count': 47540},
#     {'parameter': 'pm25 µg/m³', 'count': 46118}],
#    'count': 282352},
#   {'id': 8558,
#    'country': 'IN',
#    'city': 'Chennai',
#    'cities': ['Chennai'],
#    'location': 'US Diplomatic Post: Chennai',
#    'locations': ['US Diplomatic Post: Chennai'],
#    'sourceName': 'StateAir Chennai',
#    'sourceNames': ['StateAir Chennai'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 13.08784, 'longitude': 80.27847},
#    'firstUpdated': '2022-10-03T20:00:00+00:00',
#    'lastUpdated': '2024-08-23T11:30:00+00:00',
#    'parameters': ['pm25'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 11751}],
#    'count': 11751},
#   {'id': 352777,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Kashiram Nagar, Moradabad - UPPCB',
#    'locations': ['Kashiram Nagar, Moradabad - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.849399000000002, 'longitude': 78.742362},
#    'firstUpdated': '2022-06-20T09:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'co', 'pm10', 'o3', 'no2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 1265},
#     {'parameter': 'co µg/m³', 'count': 1265},
#     {'parameter': 'pm10 µg/m³', 'count': 1265},
#     {'parameter': 'o3 µg/m³', 'count': 1265},
#     {'parameter': 'no2 µg/m³', 'count': 1265},
#     {'parameter': 'pm25 µg/m³', 'count': 1265}],
#    'count': 7590},
#   {'id': 860,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Sanjay Palace, Agra - UPPCB',
#    'locations': ['Sanjay Palace, Agra - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 27.19865833, 'longitude': 78.00598056},
#    'firstUpdated': '2016-03-22T01:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'so2', 'no2', 'co', 'pm10', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 65110},
#     {'parameter': 'so2 µg/m³', 'count': 48203},
#     {'parameter': 'no2 µg/m³', 'count': 39799},
#     {'parameter': 'co µg/m³', 'count': 61310},
#     {'parameter': 'pm10 µg/m³', 'count': 6598},
#     {'parameter': 'pm25 µg/m³', 'count': 64910}],
#    'count': 285930},
#   {'id': 5609,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Anand Kala Kshetram, Rajamahendravaram - APPCB',
#    'locations': ['Anand Kala Kshetram, Rajamahendravaram - APPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 16.9872867, 'longitude': 81.7363176},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'no2', 'pm10', 'o3', 'so2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 41173},
#     {'parameter': 'no2 µg/m³', 'count': 41918},
#     {'parameter': 'pm10 µg/m³', 'count': 41799},
#     {'parameter': 'o3 µg/m³', 'count': 41612},
#     {'parameter': 'so2 µg/m³', 'count': 41565},
#     {'parameter': 'pm25 µg/m³', 'count': 41410}],
#    'count': 249477},
#   {'id': 8557,
#    'country': 'IN',
#    'city': 'India',
#    'cities': ['India'],
#    'location': 'Hyderabad',
#    'locations': ['Hyderabad'],
#    'sourceName': 'AirNow',
#    'sourceNames': ['AirNow'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 17.38405, 'longitude': 78.45636},
#    'firstUpdated': '2016-11-09T19:00:00+00:00',
#    'lastUpdated': '2024-08-23T11:30:00+00:00',
#    'parameters': ['pm25'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 63191}],
#    'count': 63191},
#   {'id': 10905,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Rishi Nagar, Kaithal - HSPCB',
#    'locations': ['Rishi Nagar, Kaithal - HSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 29.8006, 'longitude': 76.4155},
#    'firstUpdated': '2019-08-07T07:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'co', 'pm10', 'pm25', 'o3', 'so2'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 24696},
#     {'parameter': 'co µg/m³', 'count': 24756},
#     {'parameter': 'pm10 µg/m³', 'count': 24748},
#     {'parameter': 'pm25 µg/m³', 'count': 24739},
#     {'parameter': 'o3 µg/m³', 'count': 24757},
#     {'parameter': 'so2 µg/m³', 'count': 24763}],
#    'count': 148459},
#   {'id': 5630,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Shadipur, Delhi - CPCB',
#    'locations': ['Shadipur, Delhi - CPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.651478099999995, 'longitude': 77.1473105},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'o3', 'pm25', 'pm10', 'co', 'no2'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 49149},
#     {'parameter': 'o3 µg/m³', 'count': 49214},
#     {'parameter': 'pm25 µg/m³', 'count': 48783},
#     {'parameter': 'pm10 µg/m³', 'count': 14935},
#     {'parameter': 'co µg/m³', 'count': 48894},
#     {'parameter': 'no2 µg/m³', 'count': 49156}],
#    'count': 260131},
#   {'id': 5622,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'NSIT Dwarka, Delhi - CPCB',
#    'locations': ['NSIT Dwarka, Delhi - CPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.60909, 'longitude': 77.0325413},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'pm10', 'so2', 'pm25', 'co', 'o3'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 47282},
#     {'parameter': 'pm10 µg/m³', 'count': 13407},
#     {'parameter': 'so2 µg/m³', 'count': 47298},
#     {'parameter': 'pm25 µg/m³', 'count': 47291},
#     {'parameter': 'co µg/m³', 'count': 47298},
#     {'parameter': 'o3 µg/m³', 'count': 47283}],
#    'count': 249859},
#   {'id': 8118,
#    'country': 'IN',
#    'city': 'Delhi',
#    'cities': ['Delhi'],
#    'location': 'US Diplomatic Post: New Delhi',
#    'locations': ['US Diplomatic Post: New Delhi'],
#    'sourceName': 'StateAir NewDelhi',
#    'sourceNames': ['StateAir NewDelhi'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.63576, 'longitude': 77.22445},
#    'firstUpdated': '2016-11-09T19:00:00+00:00',
#    'lastUpdated': '2024-08-23T11:30:00+00:00',
#    'parameters': ['pm25'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 63050}],
#    'count': 63050},
#   {'id': 6975,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Silk Board, Bengaluru - KSPCB',
#    'locations': ['Silk Board, Bengaluru - KSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 12.917348000000002, 'longitude': 77.622813},
#    'firstUpdated': '2018-08-10T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'no2', 'so2', 'o3', 'pm10', 'co'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 30582},
#     {'parameter': 'no2 µg/m³', 'count': 29446},
#     {'parameter': 'so2 µg/m³', 'count': 25567},
#     {'parameter': 'o3 µg/m³', 'count': 29001},
#     {'parameter': 'pm10 µg/m³', 'count': 30603},
#     {'parameter': 'co µg/m³', 'count': 27877}],
#    'count': 173076},
#   {'id': 8172,
#    'country': 'IN',
#    'city': 'Kolkata',
#    'cities': ['Kolkata'],
#    'location': 'US Diplomatic Post: Kolkata',
#    'locations': ['US Diplomatic Post: Kolkata'],
#    'sourceName': 'StateAir Kolkata',
#    'sourceNames': ['StateAir Kolkata'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 22.56263, 'longitude': 88.36304},
#    'firstUpdated': '2022-10-03T20:00:00+00:00',
#    'lastUpdated': '2024-08-23T11:30:00+00:00',
#    'parameters': ['pm25'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 13024}],
#    'count': 13024},
#   {'id': 6978,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Knowledge Park - III, Greater Noida - UPPCB',
#    'locations': ['Knowledge Park - III, Greater Noida - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.47272, 'longitude': 77.48199999999999},
#    'firstUpdated': '2018-08-10T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'no2', 'so2', 'pm25', 'co', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 34973},
#     {'parameter': 'no2 µg/m³', 'count': 33994},
#     {'parameter': 'so2 µg/m³', 'count': 35105},
#     {'parameter': 'pm25 µg/m³', 'count': 36244},
#     {'parameter': 'co µg/m³', 'count': 32532},
#     {'parameter': 'pm10 µg/m³', 'count': 36581}],
#    'count': 209429},
#   {'id': 5635,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Adarsh Nagar, Jaipur - RSPCB',
#    'locations': ['Adarsh Nagar, Jaipur - RSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 26.902908999999998, 'longitude': 75.836858},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'so2', 'co', 'pm10', 'no2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 38796},
#     {'parameter': 'so2 µg/m³', 'count': 38774},
#     {'parameter': 'co µg/m³', 'count': 38777},
#     {'parameter': 'pm10 µg/m³', 'count': 38759},
#     {'parameter': 'no2 µg/m³', 'count': 38764},
#     {'parameter': 'pm25 µg/m³', 'count': 38784}],
#    'count': 232654},
#   {'id': 10909,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Vijay Nagar, Ramanagara - KSPCB',
#    'locations': ['Vijay Nagar, Ramanagara - KSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 12.733409, 'longitude': 77.298051},
#    'firstUpdated': '2019-09-23T10:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'pm25', 'o3', 'no2', 'so2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 20895},
#     {'parameter': 'pm25 µg/m³', 'count': 21688},
#     {'parameter': 'o3 µg/m³', 'count': 20397},
#     {'parameter': 'no2 µg/m³', 'count': 20943},
#     {'parameter': 'so2 µg/m³', 'count': 20624},
#     {'parameter': 'pm10 µg/m³', 'count': 21900}],
#    'count': 126447},
#   {'id': 301,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Vikas Sadan, Gurugram - HSPCB',
#    'locations': ['Vikas Sadan, Gurugram - HSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.4501238, 'longitude': 77.0263051},
#    'firstUpdated': '2016-03-25T08:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'pm10', 'co', 'so2', 'no2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 71652},
#     {'parameter': 'pm10 µg/m³', 'count': 36},
#     {'parameter': 'co µg/m³', 'count': 70917},
#     {'parameter': 'so2 µg/m³', 'count': 72136},
#     {'parameter': 'no2 µg/m³', 'count': 70687},
#     {'parameter': 'pm25 µg/m³', 'count': 71215}],
#    'count': 356643},
#   {'id': 228840,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Madan Mohan Malaviya University of Technology, Gorakhpur - UPPCB',
#    'locations': ['Madan Mohan Malaviya University of Technology, Gorakhpur - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 26.730136000000005, 'longitude': 83.433859},
#    'firstUpdated': '2021-06-30T23:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'so2', 'o3', 'pm10', 'pm25', 'no2'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 6549},
#     {'parameter': 'so2 µg/m³', 'count': 6549},
#     {'parameter': 'o3 µg/m³', 'count': 6549},
#     {'parameter': 'pm10 µg/m³', 'count': 6549},
#     {'parameter': 'pm25 µg/m³', 'count': 6549},
#     {'parameter': 'no2 µg/m³', 'count': 6549}],
#    'count': 39294},
#   {'id': 5590,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Ardhali Bazar, Varanasi - UPPCB',
#    'locations': ['Ardhali Bazar, Varanasi - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 25.3505986, 'longitude': 82.9083074},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'co', 'no2', 'pm10', 'o3', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 38181},
#     {'parameter': 'co µg/m³', 'count': 24022},
#     {'parameter': 'no2 µg/m³', 'count': 41686},
#     {'parameter': 'pm10 µg/m³', 'count': 28338},
#     {'parameter': 'o3 µg/m³', 'count': 43816},
#     {'parameter': 'pm25 µg/m³', 'count': 40817}],
#    'count': 216860},
#   {'id': 6986,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Knowledge Park - V, Greater Noida - UPPCB',
#    'locations': ['Knowledge Park - V, Greater Noida - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.557053999999997, 'longitude': 77.453663},
#    'firstUpdated': '2019-06-28T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'no2', 'so2', 'pm10', 'co', 'o3'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 28647},
#     {'parameter': 'no2 µg/m³', 'count': 28515},
#     {'parameter': 'so2 µg/m³', 'count': 28137},
#     {'parameter': 'pm10 µg/m³', 'count': 29274},
#     {'parameter': 'co µg/m³', 'count': 24067},
#     {'parameter': 'o3 µg/m³', 'count': 28257}],
#    'count': 166897},
#   {'id': 6923,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'New Mandi, Muzaffarnagar - UPPCB',
#    'locations': ['New Mandi, Muzaffarnagar - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 29.472350800000005,
#     'longitude': 77.71940310000001},
#    'firstUpdated': '2018-08-10T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'pm10', 'pm25', 'no2', 'co', 'so2'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 31288},
#     {'parameter': 'pm10 µg/m³', 'count': 30069},
#     {'parameter': 'pm25 µg/m³', 'count': 29656},
#     {'parameter': 'no2 µg/m³', 'count': 32420},
#     {'parameter': 'co µg/m³', 'count': 29151},
#     {'parameter': 'so2 µg/m³', 'count': 32373}],
#    'count': 184957},
#   {'id': 6443,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Bandhavgar Colony, Satna - Birla Cement',
#    'locations': ['Bandhavgar Colony, Satna - Birla Cement'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 24.584343630000003,
#     'longitude': 80.85494140000002},
#    'firstUpdated': '2018-04-16T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'pm25', 'co', 'o3', 'pm10', 'so2'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 1975},
#     {'parameter': 'pm25 µg/m³', 'count': 33230},
#     {'parameter': 'co µg/m³', 'count': 33163},
#     {'parameter': 'o3 µg/m³', 'count': 1974},
#     {'parameter': 'pm10 µg/m³', 'count': 33525},
#     {'parameter': 'so2 µg/m³', 'count': 33207}],
#    'count': 137074},
#   {'id': 358467,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Civil Lines, Bareilly - UPPCB',
#    'locations': ['Civil Lines, Bareilly - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.359580999999995,
#     'longitude': 79.41445499999999},
#    'firstUpdated': '2022-09-13T13:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'co', 'o3', 'no2', 'so2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 500},
#     {'parameter': 'co µg/m³', 'count': 500},
#     {'parameter': 'o3 µg/m³', 'count': 500},
#     {'parameter': 'no2 µg/m³', 'count': 500},
#     {'parameter': 'so2 µg/m³', 'count': 500},
#     {'parameter': 'pm10 µg/m³', 'count': 500}],
#    'count': 3000},
#   {'id': 313410,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'DM College of Science, Imphal - Manipur PCB',
#    'locations': ['DM College of Science, Imphal - Manipur PCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 24.8207389, 'longitude': 93.94230849999998},
#    'firstUpdated': '2022-04-18T13:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'so2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 2401},
#     {'parameter': 'no2 µg/m³', 'count': 2401},
#     {'parameter': 'o3 µg/m³', 'count': 2401},
#     {'parameter': 'pm10 µg/m³', 'count': 2401},
#     {'parameter': 'so2 µg/m³', 'count': 2401},
#     {'parameter': 'pm25 µg/m³', 'count': 2401}],
#    'count': 14406},
#   {'id': 5542,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Civil Line, Jalandhar - PPCB',
#    'locations': ['Civil Line, Jalandhar - PPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 31.321907, 'longitude': 75.578914},
#    'firstUpdated': '2018-03-09T04:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'so2', 'pm25', 'pm10', 'no2', 'co'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 35343},
#     {'parameter': 'so2 µg/m³', 'count': 34943},
#     {'parameter': 'pm25 µg/m³', 'count': 35289},
#     {'parameter': 'pm10 µg/m³', 'count': 35317},
#     {'parameter': 'no2 µg/m³', 'count': 35281},
#     {'parameter': 'co µg/m³', 'count': 35358}],
#    'count': 211531},
#   {'id': 301390,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Bardowali, Agartala - Tripura SPCB',
#    'locations': ['Bardowali, Agartala - Tripura SPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 23.8175497, 'longitude': 91.27269739999998},
#    'firstUpdated': '2022-03-24T21:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'o3', 'so2', 'pm10', 'pm25', 'co'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 3171},
#     {'parameter': 'o3 µg/m³', 'count': 3171},
#     {'parameter': 'so2 µg/m³', 'count': 3171},
#     {'parameter': 'pm10 µg/m³', 'count': 3171},
#     {'parameter': 'pm25 µg/m³', 'count': 3171},
#     {'parameter': 'co µg/m³', 'count': 3171}],
#    'count': 19026},
#   {'id': 6952,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'F-Block, Sirsa - HSPCB',
#    'locations': ['F-Block, Sirsa - HSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 29.536400000000004, 'longitude': 75.0158},
#    'firstUpdated': '2019-02-13T01:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'o3', 'co', 'pm10', 'so2', 'no2'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 29573},
#     {'parameter': 'o3 µg/m³', 'count': 29577},
#     {'parameter': 'co µg/m³', 'count': 29576},
#     {'parameter': 'pm10 µg/m³', 'count': 29575},
#     {'parameter': 'so2 µg/m³', 'count': 29575},
#     {'parameter': 'no2 µg/m³', 'count': 29566}],
#    'count': 177442},
#   {'id': 5623,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Central University, Hyderabad - TSPCB',
#    'locations': ['Central University, Hyderabad - TSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 17.460103, 'longitude': 78.334361},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'o3', 'pm25', 'pm10', 'no2', 'co'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 34618},
#     {'parameter': 'o3 µg/m³', 'count': 34379},
#     {'parameter': 'pm25 µg/m³', 'count': 33598},
#     {'parameter': 'pm10 µg/m³', 'count': 33402},
#     {'parameter': 'no2 µg/m³', 'count': 34498},
#     {'parameter': 'co µg/m³', 'count': 34550}],
#    'count': 205045},
#   {'id': 6942,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Phase-4 GIDC, Vatva - GPCB',
#    'locations': ['Phase-4 GIDC, Vatva - GPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 22.969611, 'longitude': 72.6435},
#    'firstUpdated': '2019-02-13T01:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'pm25', 'so2', 'pm10', 'o3', 'no2'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 27574},
#     {'parameter': 'pm25 µg/m³', 'count': 27619},
#     {'parameter': 'so2 µg/m³', 'count': 27575},
#     {'parameter': 'pm10 µg/m³', 'count': 27585},
#     {'parameter': 'o3 µg/m³', 'count': 27627},
#     {'parameter': 'no2 µg/m³', 'count': 27606}],
#    'count': 165586},
#   {'id': 5646,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Plammoodu, Thiruvananthapuram - Kerala PCB',
#    'locations': ['Plammoodu, Thiruvananthapuram - Kerala PCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 8.5149093, 'longitude': 76.9435879},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'pm25', 'so2', 'co', 'no2', 'o3'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 45278},
#     {'parameter': 'pm25 µg/m³', 'count': 44194},
#     {'parameter': 'so2 µg/m³', 'count': 47352},
#     {'parameter': 'co µg/m³', 'count': 47343},
#     {'parameter': 'no2 µg/m³', 'count': 47305},
#     {'parameter': 'o3 µg/m³', 'count': 47294}],
#    'count': 278766},
#   {'id': 270697,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Employment Office, Moradabad - UPPCB',
#    'locations': ['Employment Office, Moradabad - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.885279999999998,
#     'longitude': 78.73879999999998},
#    'firstUpdated': '2021-11-10T12:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'co', 'o3', 'pm25', 'so2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 4224},
#     {'parameter': 'co µg/m³', 'count': 4224},
#     {'parameter': 'o3 µg/m³', 'count': 4224},
#     {'parameter': 'pm25 µg/m³', 'count': 4223},
#     {'parameter': 'so2 µg/m³', 'count': 4224},
#     {'parameter': 'pm10 µg/m³', 'count': 4224}],
#    'count': 25343},
#   {'id': 6933,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Shasthri Nagar, Ratlam - IPCA Lab',
#    'locations': ['Shasthri Nagar, Ratlam - IPCA Lab'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 23.331731, 'longitude': 75.045981},
#    'firstUpdated': '2019-01-03T14:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'no2', 'pm25', 'so2'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 24486},
#     {'parameter': 'no2 µg/m³', 'count': 23903},
#     {'parameter': 'pm25 µg/m³', 'count': 24485},
#     {'parameter': 'so2 µg/m³', 'count': 24321}],
#    'count': 97195},
#   {'id': 344104,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Kompally Municipal Office, Hyderabad - TSPCB',
#    'locations': ['Kompally Municipal Office, Hyderabad - TSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 17.544899, 'longitude': 78.486949},
#    'firstUpdated': '2022-05-26T12:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'o3', 'pm10', 'co', 'no2', 'so2'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 1764},
#     {'parameter': 'o3 µg/m³', 'count': 1758},
#     {'parameter': 'pm10 µg/m³', 'count': 1767},
#     {'parameter': 'co µg/m³', 'count': 1759},
#     {'parameter': 'no2 µg/m³', 'count': 1759},
#     {'parameter': 'so2 µg/m³', 'count': 1759}],
#    'count': 10566},
#   {'id': 5569,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Punjab Agricultural University, Ludhiana - PPCB',
#    'locations': ['Punjab Agricultural University, Ludhiana - PPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 30.902800000000003, 'longitude': 75.8086},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'o3', 'pm25', 'so2', 'no2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 34111},
#     {'parameter': 'o3 µg/m³', 'count': 41022},
#     {'parameter': 'pm25 µg/m³', 'count': 41179},
#     {'parameter': 'so2 µg/m³', 'count': 41154},
#     {'parameter': 'no2 µg/m³', 'count': 41148},
#     {'parameter': 'pm10 µg/m³', 'count': 41135}],
#    'count': 239749},
#   {'id': 278671,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Shivaji Nagar, Jhansi - UPPCB',
#    'locations': ['Shivaji Nagar, Jhansi - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 25.4547, 'longitude': 78.6039},
#    'firstUpdated': '2022-02-04T13:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'pm25', 'co', 'so2', 'no2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 2793},
#     {'parameter': 'pm25 µg/m³', 'count': 2793},
#     {'parameter': 'co µg/m³', 'count': 2793},
#     {'parameter': 'so2 µg/m³', 'count': 2793},
#     {'parameter': 'no2 µg/m³', 'count': 2793},
#     {'parameter': 'pm10 µg/m³', 'count': 2793}],
#    'count': 16758},
#   {'id': 233414,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Omex Eternity, Vrindavan - UPPCB',
#    'locations': ['Omex Eternity, Vrindavan - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 27.571409, 'longitude': 77.655757},
#    'firstUpdated': '2021-08-25T17:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'o3', 'no2', 'so2', 'co', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 6356},
#     {'parameter': 'o3 µg/m³', 'count': 6356},
#     {'parameter': 'no2 µg/m³', 'count': 6356},
#     {'parameter': 'so2 µg/m³', 'count': 6356},
#     {'parameter': 'co µg/m³', 'count': 6356},
#     {'parameter': 'pm10 µg/m³', 'count': 6356}],
#    'count': 38136},
#   {'id': 6945,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Kurla, Mumbai - MPCB',
#    'locations': ['Kurla, Mumbai - MPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 19.086299999999998, 'longitude': 72.8888},
#    'firstUpdated': '2019-06-19T00:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'pm25', 'o3', 'co', 'no2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 25076},
#     {'parameter': 'pm25 µg/m³', 'count': 29589},
#     {'parameter': 'o3 µg/m³', 'count': 24859},
#     {'parameter': 'co µg/m³', 'count': 25325},
#     {'parameter': 'no2 µg/m³', 'count': 27491},
#     {'parameter': 'pm10 µg/m³', 'count': 26287}],
#    'count': 158627},
#   {'id': 5551,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Golden Temple, Amritsar - PPCB',
#    'locations': ['Golden Temple, Amritsar - PPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 31.62, 'longitude': 74.876512},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'co', 'o3', 'pm25', 'so2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 43428},
#     {'parameter': 'co µg/m³', 'count': 43519},
#     {'parameter': 'o3 µg/m³', 'count': 42972},
#     {'parameter': 'pm25 µg/m³', 'count': 43418},
#     {'parameter': 'so2 µg/m³', 'count': 43428},
#     {'parameter': 'pm10 µg/m³', 'count': 43424}],
#    'count': 260189},
#   {'id': 5610,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'North Campus, DU, Delhi - IMD',
#    'locations': ['North Campus, DU, Delhi - IMD'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.6573814, 'longitude': 77.1585447},
#    'firstUpdated': '2018-03-09T05:30:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'pm25', 'co', 'o3', 'no2', 'o3'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 37050},
#     {'parameter': 'pm25 µg/m³', 'count': 37035},
#     {'parameter': 'co µg/m³', 'count': 37076},
#     {'parameter': 'o3 ppm', 'count': 1090},
#     {'parameter': 'no2 µg/m³', 'count': 37066},
#     {'parameter': 'o3 µg/m³', 'count': 35989}],
#    'count': 185306},
#   {'id': 1236037,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Dhopagachi',
#    'locations': ['Dhopagachi'],
#    'sourceName': 'AirGradient',
#    'sourceNames': ['AirGradient'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 22.3743, 'longitude': 88.415},
#    'firstUpdated': '2023-07-15T13:00:00+00:00',
#    'lastUpdated': '2023-10-24T17:00:00+00:00',
#    'parameters': ['temperature', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'temperature c', 'count': 1698},
#     {'parameter': 'pm25 µg/m³', 'count': 1698}],
#    'count': 3396},
#   {'id': 6954,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Chikkaballapur Rural, Chikkaballapur - KSPCB',
#    'locations': ['Chikkaballapur Rural, Chikkaballapur - KSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 13.428827999999998, 'longitude': 77.731418},
#    'firstUpdated': '2018-08-10T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'pm25', 'so2', 'no2', 'o3', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 29922},
#     {'parameter': 'pm25 µg/m³', 'count': 32357},
#     {'parameter': 'so2 µg/m³', 'count': 31401},
#     {'parameter': 'no2 µg/m³', 'count': 31867},
#     {'parameter': 'o3 µg/m³', 'count': 31781},
#     {'parameter': 'pm10 µg/m³', 'count': 32612}],
#    'count': 189940},
#   {'id': 10919,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Sanjay Nagar, Ghaziabad - UPPCB',
#    'locations': ['Sanjay Nagar, Ghaziabad - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.685382, 'longitude': 77.453839},
#    'firstUpdated': '2019-04-27T12:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'o3', 'no2', 'pm10', 'pm25', 'so2'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 22705},
#     {'parameter': 'o3 µg/m³', 'count': 24924},
#     {'parameter': 'no2 µg/m³', 'count': 26082},
#     {'parameter': 'pm10 µg/m³', 'count': 26461},
#     {'parameter': 'pm25 µg/m³', 'count': 25813},
#     {'parameter': 'so2 µg/m³', 'count': 25442}],
#    'count': 151427},
#   {'id': 344144,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'IITH Kandi, Hyderabad - TSPCB',
#    'locations': ['IITH Kandi, Hyderabad - TSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 17.585705, 'longitude': 78.126199},
#    'firstUpdated': '2022-05-26T13:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'so2', 'o3', 'pm10', 'co', 'no2'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 1789},
#     {'parameter': 'so2 µg/m³', 'count': 1783},
#     {'parameter': 'o3 µg/m³', 'count': 1783},
#     {'parameter': 'pm10 µg/m³', 'count': 1789},
#     {'parameter': 'co µg/m³', 'count': 1783},
#     {'parameter': 'no2 µg/m³', 'count': 1786}],
#    'count': 10713},
#   {'id': 5647,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Sanathnagar, Hyderabad - TSPCB',
#    'locations': ['Sanathnagar, Hyderabad - TSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 17.4559458, 'longitude': 78.4332152},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'no2', 'co', 'so2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 40925},
#     {'parameter': 'no2 µg/m³', 'count': 40474},
#     {'parameter': 'co µg/m³', 'count': 40210},
#     {'parameter': 'so2 µg/m³', 'count': 40622},
#     {'parameter': 'pm25 µg/m³', 'count': 38575}],
#    'count': 200806},
#   {'id': 270877,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Eco Herbal Park, Moradabad - UPPCB',
#    'locations': ['Eco Herbal Park, Moradabad - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.840738999999996,
#     'longitude': 78.69753100000001},
#    'firstUpdated': '2022-01-20T11:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'no2', 'pm10', 'co', 'so2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 2899},
#     {'parameter': 'no2 µg/m³', 'count': 2898},
#     {'parameter': 'pm10 µg/m³', 'count': 3000},
#     {'parameter': 'co µg/m³', 'count': 2413},
#     {'parameter': 'so2 µg/m³', 'count': 2892},
#     {'parameter': 'pm25 µg/m³', 'count': 2987}],
#    'count': 17089},
#   {'id': 5628,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'GVM Corporation, Visakhapatnam - APPCB',
#    'locations': ['GVM Corporation, Visakhapatnam - APPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 17.72, 'longitude': 83.3},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'pm10', 'co', 'pm25', 'o3', 'no2'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 40963},
#     {'parameter': 'pm10 µg/m³', 'count': 39414},
#     {'parameter': 'co µg/m³', 'count': 41117},
#     {'parameter': 'pm25 µg/m³', 'count': 40134},
#     {'parameter': 'o3 µg/m³', 'count': 40944},
#     {'parameter': 'no2 µg/m³', 'count': 41081}],
#    'count': 243653},
#   {'id': 5667,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Bhopal Chauraha, Dewas - MPPCB',
#    'locations': ['Bhopal Chauraha, Dewas - MPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 22.9682591, 'longitude': 76.064118},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'pm10', 'o3', 'co', 'no2', 'so2'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 43788},
#     {'parameter': 'pm10 µg/m³', 'count': 44635},
#     {'parameter': 'o3 µg/m³', 'count': 44698},
#     {'parameter': 'co µg/m³', 'count': 43704},
#     {'parameter': 'no2 µg/m³', 'count': 43947},
#     {'parameter': 'so2 µg/m³', 'count': 44294}],
#    'count': 265066},
#   {'id': 233416,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Nagar Nigam, Prayagraj - UPPCB',
#    'locations': ['Nagar Nigam, Prayagraj - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 25.449199160000003, 'longitude': 81.82735986},
#    'firstUpdated': '2021-08-25T17:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'no2', 'so2', 'o3', 'pm25', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 6277},
#     {'parameter': 'no2 µg/m³', 'count': 6277},
#     {'parameter': 'so2 µg/m³', 'count': 6277},
#     {'parameter': 'o3 µg/m³', 'count': 6277},
#     {'parameter': 'pm25 µg/m³', 'count': 6277},
# ...
#    'locations': ['PSG College of Arts and Science, Coimbatore - TNPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 11.0328, 'longitude': 77.0349},
#    'firstUpdated': '2022-09-13T12:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'no2', 'pm25', 'o3', 'so2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 284},
#     {'parameter': 'no2 µg/m³', 'count': 302},
#     {'parameter': 'pm25 µg/m³', 'count': 231},
#     {'parameter': 'o3 µg/m³', 'count': 268},
#     {'parameter': 'so2 µg/m³', 'count': 243},
#     {'parameter': 'pm10 µg/m³', 'count': 231}],
#    'count': 1559},
#   {'id': 5559,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Collectorate, Gaya - BSPCB',
#    'locations': ['Collectorate, Gaya - BSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 24.7955, 'longitude': 84.9994},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'pm25', 'co', 'o3', 'so2'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 37524},
#     {'parameter': 'pm25 µg/m³', 'count': 37489},
#     {'parameter': 'co µg/m³', 'count': 34855},
#     {'parameter': 'o3 µg/m³', 'count': 37209},
#     {'parameter': 'so2 µg/m³', 'count': 33892}],
#    'count': 180969},
#   {'id': 6976,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Jai Bhim Nagar, Meerut - UPPCB',
#    'locations': ['Jai Bhim Nagar, Meerut - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.953588200000002, 'longitude': 77.7622941},
#    'firstUpdated': '2019-07-03T05:30:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'pm10', 'so2', 'pm25', 'co', 'no2'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 16744},
#     {'parameter': 'pm10 µg/m³', 'count': 16684},
#     {'parameter': 'so2 µg/m³', 'count': 16877},
#     {'parameter': 'pm25 µg/m³', 'count': 16798},
#     {'parameter': 'co µg/m³', 'count': 10641},
#     {'parameter': 'no2 µg/m³', 'count': 15441}],
#    'count': 93185},
#   {'id': 330021,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Vibhab Nagar, Firozabad - UPPCB',
#    'locations': ['Vibhab Nagar, Firozabad - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 27.1594, 'longitude': 78.3953},
#    'firstUpdated': '2022-05-04T07:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'so2', 'pm25', 'co', 'pm10', 'o3'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 2257},
#     {'parameter': 'so2 µg/m³', 'count': 2257},
#     {'parameter': 'pm25 µg/m³', 'count': 2257},
#     {'parameter': 'co µg/m³', 'count': 2257},
#     {'parameter': 'pm10 µg/m³', 'count': 2257},
#     {'parameter': 'o3 µg/m³', 'count': 2257}],
#    'count': 13542},
#   {'id': 5636,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Shrinath Puram, Kota - RSPCB',
#    'locations': ['Shrinath Puram, Kota - RSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 25.14389, 'longitude': 75.821256},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'pm25', 'so2', 'co', 'no2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 44387},
#     {'parameter': 'pm25 µg/m³', 'count': 44880},
#     {'parameter': 'so2 µg/m³', 'count': 44902},
#     {'parameter': 'co µg/m³', 'count': 44901},
#     {'parameter': 'no2 µg/m³', 'count': 44831},
#     {'parameter': 'pm10 µg/m³', 'count': 44887}],
#    'count': 268788},
#   {'id': 6973,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Jayanagar 5th Block, Bengaluru - KSPCB',
#    'locations': ['Jayanagar 5th Block, Bengaluru - KSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 12.920984000000002, 'longitude': 77.584908},
#    'firstUpdated': '2018-08-10T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'so2', 'no2', 'co', 'o3', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 31578},
#     {'parameter': 'so2 µg/m³', 'count': 23658},
#     {'parameter': 'no2 µg/m³', 'count': 31162},
#     {'parameter': 'co µg/m³', 'count': 27524},
#     {'parameter': 'o3 µg/m³', 'count': 31096},
#     {'parameter': 'pm25 µg/m³', 'count': 31517}],
#    'count': 176535},
#   {'id': 363601,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Girls College, Sivasagar - PCBA',
#    'locations': ['Girls College, Sivasagar - PCBA'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 26.987634000000003, 'longitude': 94.636574},
#    'firstUpdated': '2022-09-29T13:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'so2', 'co', 'o3', 'pm25', 'no2'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 270},
#     {'parameter': 'so2 µg/m³', 'count': 270},
#     {'parameter': 'co µg/m³', 'count': 270},
#     {'parameter': 'o3 µg/m³', 'count': 270},
#     {'parameter': 'pm25 µg/m³', 'count': 270},
#     {'parameter': 'no2 µg/m³', 'count': 270}],
#    'count': 1620},
#   {'id': 697,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Haldia, Haldia - WBPCB',
#    'locations': ['Haldia, Haldia - WBPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 22.06047, 'longitude': 88.109737},
#    'firstUpdated': '2016-03-22T01:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'co', 'pm25', 'pm10', 'no2', 'o3'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 54249},
#     {'parameter': 'co µg/m³', 'count': 50413},
#     {'parameter': 'pm25 µg/m³', 'count': 7397},
#     {'parameter': 'pm10 µg/m³', 'count': 55629},
#     {'parameter': 'no2 µg/m³', 'count': 50712},
#     {'parameter': 'o3 µg/m³', 'count': 35931}],
#    'count': 254331},
#   {'id': 301388,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Sardar Patel Inter College, Baghpat - UPPCB',
#    'locations': ['Sardar Patel Inter College, Baghpat - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.964949, 'longitude': 77.27876100000002},
#    'firstUpdated': '2022-03-24T21:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'so2', 'o3', 'co', 'no2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 2711},
#     {'parameter': 'so2 µg/m³', 'count': 2710},
#     {'parameter': 'o3 µg/m³', 'count': 2740},
#     {'parameter': 'co µg/m³', 'count': 1862},
#     {'parameter': 'no2 µg/m³', 'count': 2753},
#     {'parameter': 'pm25 µg/m³', 'count': 2615}],
#    'count': 15391},
#   {'id': 227535,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Manoharpur, Agra - UPPCB',
#    'locations': ['Manoharpur, Agra - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 27.23711, 'longitude': 78.01936},
#    'firstUpdated': '2021-06-04T18:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'co', 'pm25', 'o3', 'so2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 6704},
#     {'parameter': 'co µg/m³', 'count': 6704},
#     {'parameter': 'pm25 µg/m³', 'count': 6704},
#     {'parameter': 'o3 µg/m³', 'count': 6704},
#     {'parameter': 'so2 µg/m³', 'count': 6704},
#     {'parameter': 'pm10 µg/m³', 'count': 6704}],
#    'count': 40224},
#   {'id': 5611,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Chandrapur, Chandrapur - MPCB',
#    'locations': ['Chandrapur, Chandrapur - MPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 19.645324, 'longitude': 77.6345232},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm10', 'co', 'no2', 'pm25', 'o3', 'so2'],
#    'countsByMeasurement': [{'parameter': 'pm10 µg/m³', 'count': 36887},
#     {'parameter': 'co µg/m³', 'count': 39124},
#     {'parameter': 'no2 µg/m³', 'count': 39133},
#     {'parameter': 'pm25 µg/m³', 'count': 37094},
#     {'parameter': 'o3 µg/m³', 'count': 39098},
#     {'parameter': 'so2 µg/m³', 'count': 39129}],
#    'count': 230465},
#   {'id': 7005,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Loni, Ghaziabad - UPPCB',
#    'locations': ['Loni, Ghaziabad - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 28.757294, 'longitude': 77.278792},
#    'firstUpdated': '2019-04-27T11:45:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['co', 'pm25', 'no2', 'o3', 'so2', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'co µg/m³', 'count': 22666},
#     {'parameter': 'pm25 µg/m³', 'count': 25497},
#     {'parameter': 'no2 µg/m³', 'count': 25556},
#     {'parameter': 'o3 µg/m³', 'count': 25370},
#     {'parameter': 'so2 µg/m³', 'count': 24561},
#     {'parameter': 'pm10 µg/m³', 'count': 26003}],
#    'count': 149653},
#   {'id': 5652,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'IGSC Planetarium Complex, Patna - BSPCB',
#    'locations': ['IGSC Planetarium Complex, Patna - BSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 25.5941, 'longitude': 85.1376},
#    'firstUpdated': '2018-03-09T21:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'no2', 'o3', 'so2', 'co'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 32700},
#     {'parameter': 'no2 µg/m³', 'count': 32058},
#     {'parameter': 'o3 µg/m³', 'count': 25342},
#     {'parameter': 'so2 µg/m³', 'count': 29765},
#     {'parameter': 'co µg/m³', 'count': 31915}],
#    'count': 151780},
#   {'id': 234568,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'FTI Kidwai Nagar, Kanpur - UPPCB',
#    'locations': ['FTI Kidwai Nagar, Kanpur - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 26.428282, 'longitude': 80.327067},
#    'firstUpdated': '2021-09-03T11:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['o3', 'pm10', 'co', 'so2', 'no2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'o3 µg/m³', 'count': 6225},
#     {'parameter': 'pm10 µg/m³', 'count': 6225},
#     {'parameter': 'co µg/m³', 'count': 6225},
#     {'parameter': 'so2 µg/m³', 'count': 6225},
#     {'parameter': 'no2 µg/m³', 'count': 6225},
#     {'parameter': 'pm25 µg/m³', 'count': 6225}],
#    'count': 37350},
#   {'id': 5603,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Sector-2 Industrial Area, Pithampur - MPPCB',
#    'locations': ['Sector-2 Industrial Area, Pithampur - MPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 22.624758, 'longitude': 75.675238},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'pm10', 'so2', 'o3', 'no2', 'co'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 43562},
#     {'parameter': 'pm10 µg/m³', 'count': 43793},
#     {'parameter': 'so2 µg/m³', 'count': 41529},
#     {'parameter': 'o3 µg/m³', 'count': 42920},
#     {'parameter': 'no2 µg/m³', 'count': 42622},
#     {'parameter': 'co µg/m³', 'count': 40819}],
#    'count': 255245},
#   {'id': 229729,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Nagla Bhau, Firozabad - UPPCB',
#    'locations': ['Nagla Bhau, Firozabad - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 27.168897000000005, 'longitude': 78.37696},
#    'firstUpdated': '2021-07-17T23:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'so2', 'co', 'no2', 'o3', 'pm10'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 6071},
#     {'parameter': 'so2 µg/m³', 'count': 6071},
#     {'parameter': 'co µg/m³', 'count': 6071},
#     {'parameter': 'no2 µg/m³', 'count': 6071},
#     {'parameter': 'o3 µg/m³', 'count': 6071},
#     {'parameter': 'pm10 µg/m³', 'count': 6071}],
#    'count': 36426},
#   {'id': 5599,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Bollaram Industrial Area, Hyderabad - TSPCB',
#    'locations': ['Bollaram Industrial Area, Hyderabad - TSPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 17.540891, 'longitude': 78.35852799999999},
#    'firstUpdated': '2018-03-09T06:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['so2', 'pm25', 'pm10', 'o3', 'no2', 'co'],
#    'countsByMeasurement': [{'parameter': 'so2 µg/m³', 'count': 42132},
#     {'parameter': 'pm25 µg/m³', 'count': 41809},
#     {'parameter': 'pm10 µg/m³', 'count': 41648},
#     {'parameter': 'o3 µg/m³', 'count': 42110},
#     {'parameter': 'no2 µg/m³', 'count': 42035},
#     {'parameter': 'co µg/m³', 'count': 41649}],
#    'count': 251383},
#   {'id': 229252,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'NSI Kalyanpur, Kanpur - UPPCB',
#    'locations': ['NSI Kalyanpur, Kanpur - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 26.509953999999997, 'longitude': 80.249612},
#    'firstUpdated': '2021-07-09T17:00:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['no2', 'pm10', 'co', 'o3', 'so2', 'pm25'],
#    'countsByMeasurement': [{'parameter': 'no2 µg/m³', 'count': 6594},
#     {'parameter': 'pm10 µg/m³', 'count': 6594},
#     {'parameter': 'co µg/m³', 'count': 6594},
#     {'parameter': 'o3 µg/m³', 'count': 6594},
#     {'parameter': 'so2 µg/m³', 'count': 6594},
#     {'parameter': 'pm25 µg/m³', 'count': 6594}],
#    'count': 39564},
#   {'id': 5662,
#    'country': 'IN',
#    'city': None,
#    'cities': [None],
#    'location': 'Nehru Nagar, Kanpur - UPPCB',
#    'locations': ['Nehru Nagar, Kanpur - UPPCB'],
#    'sourceName': 'caaqm',
#    'sourceNames': ['caaqm'],
#    'sourceType': 'government',
#    'sourceTypes': ['government'],
#    'coordinates': {'latitude': 26.470313600000004, 'longitude': 80.3229863},
#    'firstUpdated': '2018-03-09T05:30:00+00:00',
#    'lastUpdated': '2022-10-31T02:00:00+00:00',
#    'parameters': ['pm25', 'so2', 'no2', 'pm10', 'o3', 'co'],
#    'countsByMeasurement': [{'parameter': 'pm25 µg/m³', 'count': 41838},
#     {'parameter': 'so2 µg/m³', 'count': 42221},
#     {'parameter': 'no2 µg/m³', 'count': 38304},
#     {'parameter': 'pm10 µg/m³', 'count': 6997},
#     {'parameter': 'o3 µg/m³', 'count': 42219},
#     {'parameter': 'co µg/m³', 'count': 20049}],
#    'count': 191628}]}

# %%
for loc in locations_india[1]:
    print(loc)

# %% [markdown]
# ## API endpoint measurements

# %%
status, resp = api_connection.measurements(country = 'IN', location = 'NSIT Dwarka, Delhi - CPCB', page = 1)
